# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gpt.csv').dropna(subset='gemma_al')
df["mos_align"] = (df["mos_align"] - df["mos_align"].min()) / (df["mos_align"].max() - df["mos_align"].min())
df["gpt_al"] = (df["gpt_al"] - df["gpt_al"].min()) / (df["gpt_al"].max() - df["gpt_al"].min()) 
df["mos_quality"] = (df["mos_quality"] - df["mos_quality"].min()) / (df["mos_quality"].max() - df["mos_quality"].min()) 
df["gpt_perc"] = (df["gpt_perc"] - df["gpt_perc"].min()) / (df["gpt_perc"].max() - df["gpt_perc"].min()) 
df["gemma_perc"] = (df["gemma_perc"] - df["gemma_perc"].min()) / (df["gemma_perc"].max() - df["gemma_perc"].min()) 
df["gemma_al"] = (df["gemma_al"] - df["gemma_al"].min()) / (df["gemma_al"].max() - df["gemma_al"].min())

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_align"], df["gpt_al"], alpha=0.7, edgecolors='k')
plt.xlabel("Human Rating (0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Comparison of Gpt-4o Ratings and Human Ratings (Alignment)")
plt.grid(True)
plt.show()

# Calculate the Pearson correlation coefficient
pearson_corr, pearson_p = pearsonr(df["mos_align"], df["gpt_al"])
print(f"Pearson correlation coefficient: {pearson_corr:.3f}")

# Calculate the Spearman correlation coefficient
spearman_corr, spearman_p = spearmanr(df["mos_align"], df["gpt_al"])
print(f"Spearman correlation coefficient: {spearman_corr:.3f}")

# Build a linear regression model
X = df["mos_align"].values.reshape(-1, 1)
y = df["gpt_al"].values
model = LinearRegression()
model.fit(X, y)
r2 = model.score(X, y)
print(f"Coefficient of determination (R²): {r2:.3f}")

# Visualization of the regression model
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_align"], df["gpt_al"], alpha=0.7, edgecolors='k', label="Data")
x_line = np.linspace(df["mos_align"].min(), df["mos_align"].max(), 100)
y_line = model.predict(x_line.reshape(-1, 1))
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear Regression")
plt.xlabel("Human Rating (normalized, 0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Linear Regression: Gpt-4o Rating vs. Human Rating (Alignment)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pearson correlation coefficient: 0.781
# Spearman correlation coefficient: 0.754
# Coefficient of determination (R²): 0.609

# %%
df.columns[-10:]
# Out:
# Index(['adj2', 'style', 'mos_quality', 'std_quality', 'mos_align', 'std_align',
#        'gemma_al', 'gemma_perc', 'gpt_al', 'gpt_perc'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_quality"], df["gpt_perc"], alpha=0.7, edgecolors='k')
plt.xlabel("Human Rating (0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Comparison of Gpt-4o Ratings and Human Ratings (Quality)")
plt.grid(True)
plt.show()

# Calculate the Pearson correlation coefficient
pearson_corr, pearson_p = pearsonr(df["mos_quality"], df["gpt_perc"])
print(f"Pearson correlation coefficient: {pearson_corr:.3f}")

# Calculate the Spearman correlation coefficient
spearman_corr, spearman_p = spearmanr(df["mos_quality"], df["gpt_perc"])
print(f"Spearman correlation coefficient: {spearman_corr:.3f}")

# Build a linear regression model
X = df["mos_quality"].values.reshape(-1, 1)
y = df["gpt_perc"].values
model = LinearRegression()
model.fit(X, y)
r2 = model.score(X, y)
print(f"Coefficient of determination (R²): {r2:.3f}")

# Visualization of the regression model
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_quality"], df["gpt_perc"], alpha=0.7, edgecolors='k', label="Data")
x_line = np.linspace(df["mos_quality"].min(), df["mos_quality"].max(), 100)
y_line = model.predict(x_line.reshape(-1, 1))
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear Regression")
plt.xlabel("Human Rating (normalized, 0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Linear Regression: Gpt-4o Rating vs. Human Rating (Quality)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pearson correlation coefficient: 0.785
# Spearman correlation coefficient: 0.712
# Coefficient of determination (R²): 0.617

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_quality"], df["gemma_perc"], alpha=0.7, edgecolors='k')
plt.xlabel("Human Rating (0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Comparison of Gemma Ratings and Human Ratings (Quality)")
plt.grid(True)
plt.show()

# Calculate the Pearson correlation coefficient
pearson_corr, pearson_p = pearsonr(df["mos_quality"], df["gemma_perc"])
print(f"Pearson correlation coefficient: {pearson_corr:.3f}")

# Calculate the Spearman correlation coefficient
spearman_corr, spearman_p = spearmanr(df["mos_quality"], df["gemma_perc"])
print(f"Spearman correlation coefficient: {spearman_corr:.3f}")

# Build a linear regression model
X = df["mos_quality"].values.reshape(-1, 1)
y = df["gemma_perc"].values
model = LinearRegression()
model.fit(X, y)
r2 = model.score(X, y)
print(f"Coefficient of determination (R²): {r2:.3f}")

# Visualization of the regression model
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_quality"], df["gemma_perc"], alpha=0.7, edgecolors='k', label="Data")
x_line = np.linspace(df["mos_quality"].min(), df["mos_quality"].max(), 100)
y_line = model.predict(x_line.reshape(-1, 1))
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear Regression")
plt.xlabel("Human Rating (normalized, 0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Linear Regression: Gemma Rating vs. Human Rating (Quality)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pearson correlation coefficient: 0.642
# Spearman correlation coefficient: 0.619
# Coefficient of determination (R²): 0.412

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_align"], df["gemma_al"], alpha=0.7, edgecolors='k')
plt.xlabel("Human Rating (0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Comparison of Gemma Ratings and Human Ratings (Alignment)")
plt.grid(True)
plt.show()

# Calculate the Pearson correlation coefficient
pearson_corr, pearson_p = pearsonr(df["mos_align"], df["gemma_al"])
print(f"Pearson correlation coefficient: {pearson_corr:.3f}")

# Calculate the Spearman correlation coefficient
spearman_corr, spearman_p = spearmanr(df["mos_align"], df["gemma_al"])
print(f"Spearman correlation coefficient: {spearman_corr:.3f}")

# Build a linear regression model
X = df["mos_align"].values.reshape(-1, 1)
y = df["gemma_al"].values
model = LinearRegression()
model.fit(X, y)
r2 = model.score(X, y)
print(f"Coefficient of determination (R²): {r2:.3f}")

# Visualization of the regression model
plt.figure(figsize=(8, 6))
plt.scatter(df["mos_align"], df["gemma_al"], alpha=0.7, edgecolors='k', label="Data")
x_line = np.linspace(df["mos_align"].min(), df["mos_align"].max(), 100)
y_line = model.predict(x_line.reshape(-1, 1))
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear Regression")
plt.xlabel("Human Rating (normalized, 0-1)")
plt.ylabel("LLM Rating (0-1)")
plt.title("Linear Regression: Gemma Rating vs. Human Rating (Alignment)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pearson correlation coefficient: 0.728
# Spearman correlation coefficient: 0.699
# Coefficient of determination (R²): 0.530
